# %%
import pandas as pd

# %%
bnb = pd.read_csv('listings.csv')

# %%
bnb
# Out:
#              id                                               name    host_id  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi       3159
# 1         20168       Studio with private bathroom in the centre 1      59484
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan      56142
# 3         27886  Romantic, stylish B&B houseboat in canal district      97647
# 4         28871                            Comfortable double room     124245
# 5         29051                            Comfortable single room     124245
# 6         31080                2-story apartment + rooftop terrace     133488
# 7         38266                Nice and quiet place in the Jordaan     164204
# 8         41125                  Amsterdam Center Entire Apartment     178515
# 9         42970        Comfortable room@PERFECT location + 2 bikes     187580
# 10        43109                   Oasis in the middle of Amsterdam     188098
# ...

# %%
bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20337 entries, 0 to 20336
# Data columns (total 16 columns):
# id                                20337 non-null int64
# name                              20302 non-null object
# host_id                           20337 non-null int64
# host_name                         20313 non-null object
# neighbourhood_group               0 non-null float64
# neighbourhood                     20337 non-null object
# latitude                          20337 non-null float64
# longitude                         20337 non-null float64
# room_type                         20337 non-null object
# price                             20337 non-null int64
# minimum_nights                    20337 non-null int64
# number_of_reviews                 20337 non-null int64
# last_review                       17797 non-null object
# reviews_per_month                 17797 non-null float64
# calculated_host_listings_count    20337 non-null int64
# ...

# %%
bnb['host_name']
# Out:
# 0                Daniel
# 1             Alexander
# 2                  Joan
# 3                  Flip
# 4                 Edwin
# 5                 Edwin
# 6                Nienke
# 7                Julian
# 8                 Fatih
# 9                 Micha
# 10                Aukje
# 11                   Ym
# 12                  Jan
# 13                Joost
# 14                 Ivar
# 15             Franklin
# 16          Joanna & MP
# 17                Nikki
# 18              Raymond
# 19                Evert
# 20           VictorLuke
# 21                 DoJo
# 22                Georg
# 23                 DoJo
# 24                Lotte
# 25              Bharati
# 26                Arjan
# 27           Jan-Willem
# 28            Rai & Clo
# 29             Cornelie
#               ...
# 20307             Jonny
# 20308           Mathieu
# 20309    Wim  En Coosje
# 20310           Karsten
# 20311             Tanja
# 20312            Maikel
# 20313             Danny
# ...

# %%
bnb[bnb['host_name'].isnull()]
# Out:
#              id                                               name    host_id  \
# 2699    4789122                             Bright Room, Amsterdam    5780127
# 2808    4989800                           Flat in historical heart   25726639
# 3485    6345018                             appartment with garden   31857493
# 5739   10227700                                        Leuke Kamer   52558016
# 8428   14292432           Typical apt in idyllic part of Amsterdam   26192345
# 8457   14327200     1 p  room, use of garden, kitchen and bathroom   44175289
# 8524   14443927       Family house in Dutch countryside near A'dam   88932190
# 8568   14504175    2 person bedroom,use of garden,kitchen,bathroom   44175289
# 8732   14819551                   Vondelpark Room, Museum district    5780127
# 8851   15044856       Boutique Loft Canal House in the city center    7369703
# 9567   16253557                       Small room with  garden view   44175289
# ...

# %%
bnb = bnb.dropna(subset=['name'])

# %%
bnb = bnb.drop('host_name' , axis = 1)

# %%
bnb = bnb.drop('host_id' , axis = 1)

# %%
bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20302 entries, 0 to 20336
# Data columns (total 14 columns):
# id                                20302 non-null int64
# name                              20302 non-null object
# neighbourhood_group               0 non-null float64
# neighbourhood                     20302 non-null object
# latitude                          20302 non-null float64
# longitude                         20302 non-null float64
# room_type                         20302 non-null object
# price                             20302 non-null int64
# minimum_nights                    20302 non-null int64
# number_of_reviews                 20302 non-null int64
# last_review                       17772 non-null object
# reviews_per_month                 17772 non-null float64
# calculated_host_listings_count    20302 non-null int64
# availability_365                  20302 non-null int64
# dtypes: float64(4), int64(6), object(4)
# memory usage: 2.3+ MB

# %%
bnb = bnb.drop(columns = 'neighbourhood_group')

# %%
bnb = bnb.reset_index(drop = True)

# %%
bnb
# Out:
#              id                                               name  \
# 0          2818           Quiet Garden View Room & Super Fast WiFi
# 1         20168       Studio with private bathroom in the centre 1
# 2         25428    Lovely apt in City Centre (w.lift) near Jordaan
# 3         27886  Romantic, stylish B&B houseboat in canal district
# 4         28871                            Comfortable double room
# 5         29051                            Comfortable single room
# 6         31080                2-story apartment + rooftop terrace
# 7         38266                Nice and quiet place in the Jordaan
# 8         41125                  Amsterdam Center Entire Apartment
# 9         42970        Comfortable room@PERFECT location + 2 bikes
# 10        43109                   Oasis in the middle of Amsterdam
# 11        43980  View into park / museum district (long/short s...
# 12        44391                 Amsterdam Centre, 3-room Apartment
# ...

# %%
bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20302 entries, 0 to 20301
# Data columns (total 13 columns):
# id                                20302 non-null int64
# name                              20302 non-null object
# neighbourhood                     20302 non-null object
# latitude                          20302 non-null float64
# longitude                         20302 non-null float64
# room_type                         20302 non-null object
# price                             20302 non-null int64
# minimum_nights                    20302 non-null int64
# number_of_reviews                 20302 non-null int64
# last_review                       17772 non-null object
# reviews_per_month                 17772 non-null float64
# calculated_host_listings_count    20302 non-null int64
# availability_365                  20302 non-null int64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 2.0+ MB

# %%
bnb[['reviews_per_month', 'last_review']] = bnb[['reviews_per_month', 'last_review']].fillna(0)

# %%
bnb['last_review']
# Out:
# 0        2019-06-28
# 1        2019-07-08
# 2        2019-05-11
# 3        2019-07-01
# 4        2019-07-02
# 5        2019-06-29
# 6        2017-10-16
# 7        2019-05-19
# 8        2019-06-23
# 9        2019-07-01
# 10       2019-07-06
# 11       2018-02-18
# 12       2019-05-12
# 13       2018-01-03
# 14       2019-06-19
# 15       2019-06-29
# 16       2019-06-30
# 17       2019-06-20
# 18       2019-06-24
# 19       2019-03-26
# 20       2019-06-24
# 21       2019-06-29
# 22       2019-07-02
# 23       2019-07-06
# 24       2019-06-22
# 25       2019-06-14
# 26       2016-10-19
# 27       2019-03-27
# 28       2019-06-23
# 29       2019-05-31
#             ...
# 20272    2019-07-07
# 20273             0
# 20274             0
# 20275             0
# 20276             0
# 20277             0
# 20278             0
# 20279             0
# 20280             0
# 20281             0
# 20282             0
# 20283             0
# 20284             0
# 20285             0
# ...

# %%
bnb['reviews_per_month'].head()
# Out:
# 0    2.09
# 1    2.45
# 2    0.17
# 3    2.14
# 4    2.56
# Name: reviews_per_month, dtype: float64

# %%
bnb['number_of_reviews'].head()
# Out:
# 0    262
# 1    279
# 2      3
# 3    195
# 4    277
# Name: number_of_reviews, dtype: int64

# %%
bnb[['reviews_per_month','price']].corr()
# Out:
#                    reviews_per_month     price
# reviews_per_month           1.000000 -0.077913
# price                      -0.077913  1.000000

# %%
bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20302 entries, 0 to 20301
# Data columns (total 13 columns):
# id                                20302 non-null int64
# name                              20302 non-null object
# neighbourhood                     20302 non-null object
# latitude                          20302 non-null float64
# longitude                         20302 non-null float64
# room_type                         20302 non-null object
# price                             20302 non-null int64
# minimum_nights                    20302 non-null int64
# number_of_reviews                 20302 non-null int64
# last_review                       20302 non-null object
# reviews_per_month                 20302 non-null float64
# calculated_host_listings_count    20302 non-null int64
# availability_365                  20302 non-null int64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 2.0+ MB

# %%
bnb.nunique()
# Out:
# id                                20302
# name                              19849
# neighbourhood                        22
# latitude                           6145
# longitude                         10013
# room_type                             3
# price                               458
# minimum_nights                       57
# number_of_reviews                   391
# last_review                        1368
# reviews_per_month                   742
# calculated_host_listings_count       26
# availability_365                    366
# dtype: int64

# %%
#Groupby
bnb.groupby('room_type').median()
# Out:
#                        id  latitude  longitude  price  minimum_nights  \
# room_type
# Entire home/apt  16719475  52.36437    4.88605    145               3
# Private room     18887670  52.36569    4.89037     89               2
# Shared room      20777194  52.36819    4.89650     55               1
#
#                  number_of_reviews  reviews_per_month  \
# room_type
# Entire home/apt                  8               0.37
# Private room                    18               1.22
# Shared room                      4               0.66
#
#                  calculated_host_listings_count  availability_365
# room_type
# Entire home/apt                               1                 0
# Private room                                  1                35
# Shared room                                   2                23

# %%
bnb.groupby('room_type').count().transpose()
# Out:
# room_type                       Entire home/apt  Private room  Shared room
# id                                        16120          4111           71
# name                                      16120          4111           71
# neighbourhood                             16120          4111           71
# latitude                                  16120          4111           71
# longitude                                 16120          4111           71
# price                                     16120          4111           71
# minimum_nights                            16120          4111           71
# number_of_reviews                         16120          4111           71
# last_review                               16120          4111           71
# reviews_per_month                         16120          4111           71
# calculated_host_listings_count            16120          4111           71
# ...
